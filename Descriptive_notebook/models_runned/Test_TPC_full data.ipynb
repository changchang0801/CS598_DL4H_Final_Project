# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Below steps are to set python to 3.6 first

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.6
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.6 1
# !sudo update-alternatives --config python3
# !python3 --version

# %%
# !sudo apt-get install python3.6-distutils
# !wget https://bootstrap.pypa.io/pip/3.6/get-pip.py
# !python get-pip.py
# !sudo apt install python3-pip
# !python -m pip install --upgrade pip

# %% [markdown]
# Next, check GPU resource first:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Mar 21 05:01:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Check CPU resources:

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# I have git cloned from orginal paper

# %%
# %cd /content/gdrive/MyDrive/TPC-Project/TPC-LoS-prediction/
# Out:
# /content/gdrive/MyDrive/TPC-Project/TPC-LoS-prediction

# %% [markdown]
# Deleted shap version number otherwise can't install;
# Also Torch 1.5.0 appear to be working fine

# %%
! pip install -r requirements.txt

# %% [markdown]
# Somehow need to reinstall these two modules

# %%
# !pip install ipykernel
# !pip install TensorBoard

# %% [markdown]
# Manually add "--model_type" in initialise_arguments.py!

# %%
# !python3 -m models.run_tpc --dataset eICU --task LoS --model_type tpc --percentage_data 100.0 --n_layers 4 --kernel_size 3 --no_temp_kernels 10 --point_size 10 --last_linear_size 20 --diagnosis_size 20 --batch_size 64 --learning_rate 0.001 --main_dropout_rate 0.3 --temp_dropout_rate 0.1
# Out:
# Config:
# {
#     "L2_regularisation": 0,
#     "alpha": 100,
#     "base_dir": "models/experiments/eICU/LoS/TPC",
#     "batch_size": 64,
#     "batch_size_test": 32,
#     "batchnorm": "mybatchnorm",
#     "dataset": "eICU",
#     "diagnosis_size": 20,
#     "disable_cuda": false,
#     "exp_name": "TPC",
#     "intermediate_reporting": false,
#     "kernel_size": 3,
#     "labs_only": false,
#     "last_linear_size": 20,
#     "learning_rate": 0.001,
#     "loss": "msle",
#     "main_dropout_rate": 0.3,
#     "mode": "train",
#     "model_type": "tpc",
#     "n_epochs": 15,
#     "n_layers": 4,
#     "name": "TPC",
#     "no_diag": false,
#     "no_exp": false,
#     "no_labs": false,
#     "no_mask": false,
#     "no_skip_connections": false,
#     "no_temp_kernels": 10,
#     "percentage_data": 100.0,
#     "point_size": 10,
#     "point_sizes": [
#         10,
#         10,
#         10,
#         10
#     ],
#     "save_results_csv": false,
#     "seed": 3490628432,
#     "share_weights": false,
#     "shuffle_train": false,
#     "sum_losses": true,
#     "task": "LoS",
#     "temp_dropout_rate": 0.1,
#     "temp_kernels": [
#         10,
#         10,
#         10,
#         10
#     ]
# }
# Experiment set up.
# TempPointConv(
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (hardtanh): Hardtanh(min_val=0.020833333333333332, max_val=100)
#   (msle_loss): MSLELoss(
#     (squared_error): MSELoss()
#   )
#   (mse_loss): MSELoss(
#     (squared_error): MSELoss()
#   )
#   (bce_loss): BCELoss()
#   (main_dropout): Dropout(p=0.3, inplace=False)
#   (temp_dropout): Dropout(p=0.1, inplace=False)
#   (empty_module): EmptyModule()
#   (diagnosis_encoder): Linear(in_features=293, out_features=20, bias=True)
#   (bn_diagnosis_encoder): MyBatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_los): MyBatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_point_last_mort): MyBatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (point_final_los): Linear(in_features=20, out_features=1, bias=True)
#   (point_final_mort): Linear(in_features=20, out_features=1, bias=True)
#   (layer_modules): ModuleDict(
#     (0): ModuleDict(
#       (bn_point): MyBatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_temp): MyBatchNorm1d(870, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=241, out_features=10, bias=True)
#       (temp): Conv1d(174, 870, kernel_size=(3,), stride=(1,), groups=87)
#     )
#     (1): ModuleDict(
#       (bn_point): MyBatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_temp): MyBatchNorm1d(970, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1121, out_features=10, bias=True)
#       (temp): Conv1d(1067, 970, kernel_size=(3,), stride=(1,), dilation=(2,), groups=97)
#     )
#     (2): ModuleDict(
#       (bn_point): MyBatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_temp): MyBatchNorm1d(1070, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1221, out_features=10, bias=True)
#       (temp): Conv1d(1177, 1070, kernel_size=(3,), stride=(1,), dilation=(4,), groups=107)
#     )
#     (3): ModuleDict(
#       (bn_point): MyBatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_temp): MyBatchNorm1d(1170, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (point): Linear(in_features=1321, out_features=10, bias=True)
#       (temp): Conv1d(1287, 1170, kernel_size=(3,), stride=(1,), dilation=(6,), groups=117)
#     )
#   )
#   (point_last_los): Linear(in_features=1482, out_features=20, bias=True)
#   (point_last_mort): Linear(in_features=1482, out_features=20, bias=True)
# )
# Experiment started.
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1068730  754997  160563   58615   26281   13702    7381    4205    7134
#      1395]
#  [ 417056  496862  165123   74301   37040   19391   10899    6347    9934
#      1498]
#  [ 182910  291146  129470   67881   36908   20390   11690    7013   11092
#      1493]
#  [  90844  176810   97827   57846   33302   19114   11214    6577   10953
#      1543]
#  [  50082  114108   73978   47109   28431   17027   10466    6212   10408
#      1455]
#  [  30374   77050   56189   38574   24643   15106    9254    5753    9765
#      1347]
#  [  19568   54026   44019   31960   20807   13352    8114    5190    9089
#      1315]
#  [  12433   39176   34775   26640   17924   11431    7285    4627    8272
#      1178]
#  [  28783  107633  108541   88358   62746   41704   27561   18048   33287
#      5165]
#  [  13458   53321   65011   57685   44103   31190   21607   14702   29754
#      5997]]
# Mean absolute deviation (MAD) = 2.761453357605545
# Mean squared error (MSE) = 34.766498731744285
# Mean absolute percentage error (MAPE) = 132.40538003411606
# Mean squared logarithmic error (MSLE) = 1.605221228899622
# R^2 Score = 0.051728137447430544
# Cohen kappa score = 0.2825242710861481
# Epoch: 0 | Train Loss: 100.9972
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[230229 165593  32573  11694   5465   2629    960    436    348     15]
#  [ 79443 112592  37203  17896   9136   4270   1604    613    481      4]
#  [ 30904  64014  29702  17798   9958   5150   2337    931    598      0]
#  [ 14009  36759  21119  15194   9784   5197   2675   1222    822      6]
#  [  6801  21771  15507  12004   8943   5367   2702   1410   1036      1]
#  [  3909  14316  11479   9403   7579   5031   2682   1569   1167     13]
#  [  2460   8998   8522   7275   6090   4476   2675   1614   1321     29]
#  [  1583   6160   6331   5876   5131   3825   2738   1618   1355      8]
#  [  3031  15720  17148  18592  18261  14849   9954   6205   7424     12]
#  [  1554   6952   9315  10444  10860  10409   8230   5879   8008     37]]
# Mean absolute deviation (MAD) = 2.586608399905309
# Mean squared error (MSE) = 56.69686122594008
# Mean absolute percentage error (MAPE) = 118.36442341693763
# Mean squared logarithmic error (MSLE) = 1.3723803847386717
# R^2 Score = 0.08076403841423807
# Cohen kappa score = 0.3639435969792997
# Epoch: 0 | Validation Loss: 85.6583
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1116382  720873  156416   55293   24623   12457    6635    3734    5878
#       712]
#  [ 407132  495228  173660   77792   37897   19547   10911    6136    9118
#      1030]
#  [ 167459  285099  137955   74087   40124   22300   12582    7434   11582
#      1371]
#  [  77557  168570  103455   63190   36894   21608   12805    7674   12617
#      1660]
#  [  40757  104006   76456   51255   32221   19721   11962    7766   13283
#      1849]
#  [  23426   67629   56593   41591   27416   17856   11359    7121   13174
#      1890]
#  [  14101   45297   43264   34271   23542   15513   10208    6698   12507
#      2039]
#  [   8618   31022   32866   27948   20482   13669    9222    6159   11806
#      1949]
#  [  18603   78279   94977   88607   69456   50483   35447   24541   51434
#      9999]
#  [   7362   34308   48727   53644   47036   37490   28307   20620   47621
#     11713]]
# Mean absolute deviation (MAD) = 2.623105544452795
# Mean squared error (MSE) = 32.184871533745046
# Mean absolute percentage error (MAPE) = 121.94129402273187
# Mean squared logarithmic error (MSLE) = 1.4300410946798163
# R^2 Score = 0.12214317838532718
# Cohen kappa score = 0.3479384339011342
# Epoch: 1 | Train Loss: 89.9751
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[241457 154438  32743  11296   5070   2573   1210    526    595     34]
#  [ 79636 109388  39278  18258   8477   4254   1962    969    992     28]
#  [ 29185  61716  31618  18207   9828   5142   2848   1450   1369     29]
#  [ 12575  34506  22763  14862   9490   5688   3282   1725   1851     45]
#  [  5891  19803  15988  12066   8349   5997   3330   1783   2273     62]
#  [  3196  12660  11626   9351   7198   5143   3344   1900   2658     72]
#  [  1922   7509   8563   7029   5858   4687   2892   1901   2959    140]
#  [  1185   4933   6111   5466   5022   4009   2763   1890   3148     98]
#  [  2113  11472  15494  15604  16496  14189  11786   8177  15400    465]
#  [   967   4874   7320   8279   9203   9769   9071   7073  14621    511]]
# Mean absolute deviation (MAD) = 2.487021495684217
# Mean squared error (MSE) = 54.51929920836982
# Mean absolute percentage error (MAPE) = 114.7600909027972
# Mean squared logarithmic error (MSLE) = 1.2669646318918348
# R^2 Score = 0.11606922589466984
# Cohen kappa score = 0.4174532934389157
# Epoch: 1 | Validation Loss: 79.0756
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1148509  695624  154027   54307   23438   11623    6151    3424    5266
#       634]
#  [ 411624  490064  175975   78181   37315   19281   10211    6019    8693
#      1088]
#  [ 164756  281769  142851   75410   40084   22026   12486    7352   11789
#      1470]
#  [  74095  164481  106924   64648   38027   21670   12974    7969   13309
#      1933]
#  [  37387   99333   78435   53147   33648   20455   12594    8087   13995
#      2195]
#  [  20480   63573   57394   43035   28708   18642   11768    7797   14325
#      2333]
#  [  12038   41576   43239   35014   24518   16473   10775    7217   14061
#      2529]
#  [   7236   27386   32517   28628   20914   14636    9721    6687   13432
#      2584]
#  [  14724   65173   90013   88341   71779   53383   38205   26825   59665
#     13718]
#  [   5616   26900   43020   50617   46487   38013   29873   22456   56947
#     16899]]
# Mean absolute deviation (MAD) = 2.5639733374855567
# Mean squared error (MSE) = 31.092400356841296
# Mean absolute percentage error (MAPE) = 118.1649193322138
# Mean squared logarithmic error (MSLE) = 1.3621111241262238
# R^2 Score = 0.15194082023879385
# Cohen kappa score = 0.37642930962738375
# Epoch: 2 | Train Loss: 85.6998
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[255603 143548  31010  10530   4612   2287   1112    546    669     25]
#  [ 83654 107197  39106  17544   7798   3747   2043    981   1130     42]
#  [ 29813  60853  32331  18117   9532   4847   2646   1497   1671     85]
#  [ 12676  33728  22995  15110   9374   5693   3165   1718   2165    163]
#  [  5777  18921  16172  12326   8624   5645   3434   1769   2737    137]
#  [  3013  11884  11576   9619   7281   4977   3520   2038   3043    197]
#  [  1744   6758   8361   7548   5759   4495   3130   1928   3406    331]
#  [  1089   4412   5725   5769   4913   4064   2804   1946   3642    261]
#  [  1794   9506  14006  16060  15855  14441  11534   8818  17790   1392]
#  [   711   3917   6177   8148   8956   9255   9278   7663  16550   1033]]
# Mean absolute deviation (MAD) = 2.43964223790539
# Mean squared error (MSE) = 53.77670602935705
# Mean absolute percentage error (MAPE) = 109.33323709775848
# Mean squared logarithmic error (MSLE) = 1.2000334856356756
# R^2 Score = 0.12810901681460374
# Cohen kappa score = 0.44210642826031044
# Epoch: 2 | Validation Loss: 74.9007
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1170566  680125  151280   52975   22571   10805    5845    3266    4947
#       623]
#  [ 416184  487701  176082   77653   36861   18758    9880    5655    8591
#      1086]
#  [ 162947  280894  144197   76842   40106   22035   12381    7300   11744
#      1547]
#  [  71835  161774  109175   65884   38108   22030   13352    8078   13663
#      2131]
#  [  35351   96776   79407   54190   34169   20807   12976    8175   14964
#      2461]
#  [  19128   60315   58070   43633   29732   19190   12151    8079   15036
#      2721]
#  [  10644   38897   42991   35802   25303   16885   11285    7648   15066
#      2919]
#  [   6353   25338   31826   29088   21572   15085   10231    6920   14277
#      3051]
#  [  12281   57854   85090   88090   72616   54717   39999   28786   65625
#     16768]
#  [   4476   22775   38970   47567   45975   38727   30958   23799   62745
#     20836]]
# Mean absolute deviation (MAD) = 2.5235052872893826
# Mean squared error (MSE) = 30.357531105959414
# Mean absolute percentage error (MAPE) = 115.57542560994183
# Mean squared logarithmic error (MSLE) = 1.3186068490695135
# R^2 Score = 0.1719847090020329
# Cohen kappa score = 0.39554794194455956
# Epoch: 3 | Train Loss: 82.9630
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[258195 138800  32232  11069   4869   2355   1151    600    635     36]
#  [ 82532 104445  40563  18838   8275   4038   2176   1114   1196     65]
#  [ 28656  58926  32888  19195   9984   5272   2925   1571   1852    123]
#  [ 11941  31842  23418  15746   9834   5864   3440   1998   2478    226]
#  [  5213  17566  16046  12667   9174   5717   3661   2119   3190    189]
#  [  2723  10781  11081  10038   7593   5186   3650   2257   3543    296]
#  [  1524   5932   7937   7631   6013   4663   3269   2092   4053    346]
#  [   939   3605   5557   5804   5011   4029   2930   2159   4260    331]
#  [  1546   7555  12291  15386  15703  14898  12197   9185  20303   2132]
#  [   516   2992   5266   7426   8362   9407   9188   7754  19135   1642]]
# Mean absolute deviation (MAD) = 2.4009711746442064
# Mean squared error (MSE) = 52.9670936837921
# Mean absolute percentage error (MAPE) = 109.04232691759334
# Mean squared logarithmic error (MSLE) = 1.164369991504583
# R^2 Score = 0.14123540100757204
# Cohen kappa score = 0.4629106999541267
# Epoch: 3 | Validation Loss: 72.6755
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1188303  671001  146471   51400   21657   10520    5464    2996    4616
#       575]
#  [ 419731  488521  174606   76591   35993   18202    9732    5533    8524
#      1018]
#  [ 162542  281588  144337   76482   40223   21814   12380    7398   11626
#      1603]
#  [  70563  160964  109207   66920   38381   22266   13393    8162   14036
#      2138]
#  [  34192   94691   80135   55305   34273   21173   13303    8343   15253
#      2608]
#  [  17927   58816   57737   44397   30048   19464   12536    8259   15913
#      2958]
#  [   9890   37322   42446   35946   25792   17478   11725    7750   15871
#      3220]
#  [   5795   24035   30953   28818   21919   15532   10384    7358   15494
#      3453]
#  [  11132   52577   80311   86216   73418   56080   41498   30174   70969
#     19451]
#  [   3943   20148   36037   45641   44155   38538   31455   24659   67597
#     24655]]
# Mean absolute deviation (MAD) = 2.491612651827734
# Mean squared error (MSE) = 29.834011389252186
# Mean absolute percentage error (MAPE) = 113.37971381545407
# Mean squared logarithmic error (MSLE) = 1.2863569588654362
# R^2 Score = 0.1862639443278401
# Cohen kappa score = 0.4108110673095856
# Epoch: 4 | Train Loss: 80.9316
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[261974 133178  32616  11616   5268   2583   1262    663    741     41]
#  [ 82264 100967  41639  19502   8840   4718   2387   1231   1612     82]
#  [ 28132  55882  33309  19946  10626   5669   3361   1774   2497    196]
#  [ 11478  29621  23309  16177  10230   6289   3703   2434   3256    290]
#  [  4934  15855  15475  13073   9087   6368   3919   2414   4027    390]
#  [  2456   9578  10613   9800   7709   5571   3902   2580   4394    545]
#  [  1360   5084   7198   7571   6196   4782   3334   2391   4902    642]
#  [   859   3122   4894   5458   5072   4144   3102   2270   5066    638]
#  [  1345   6200  10507  13577  14517  14488  12655   9985  24279   3643]
#  [   440   2506   4246   6116   6993   7881   8778   8308  22315   4105]]
# Mean absolute deviation (MAD) = 2.359433969725081
# Mean squared error (MSE) = 51.639928152203176
# Mean absolute percentage error (MAPE) = 109.30832887218426
# Mean squared logarithmic error (MSLE) = 1.1311459899952099
# R^2 Score = 0.16275296401254946
# Cohen kappa score = 0.48835323310582057
# Epoch: 4 | Validation Loss: 70.6018
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1203419  662916  142995   49773   20948    9926    5108    2920    4400
#       598]
#  [ 423231  488630  174244   75470   35162   17735    9375    5362    8184
#      1058]
#  [ 162131  281983  145413   76243   40061   21364   12470    7096   11603
#      1629]
#  [  68858  160927  110163   67294   38302   22686   13289    8083   14125
#      2303]
#  [  32856   93932   80323   55452   35053   21254   13354    8540   15843
#      2669]
#  [  16812   57330   57853   44899   30396   19749   12915    8348   16605
#      3148]
#  [   9322   35661   42336   36246   26048   17846   11997    7948   16415
#      3621]
#  [   5382   22419   30715   29062   22162   15728   10816    7564   16084
#      3809]
#  [  10218   48054   77039   84961   73363   57239   42299   31268   75018
#     22367]
#  [   3301   17600   33753   43837   43503   38388   31126   25005   71003
#     29312]]
# Mean absolute deviation (MAD) = 2.4635697717615948
# Mean squared error (MSE) = 29.345702827076316
# Mean absolute percentage error (MAPE) = 111.56416290653968
# Mean squared logarithmic error (MSLE) = 1.2583090773162953
# R^2 Score = 0.19958277960451642
# Cohen kappa score = 0.4237449374178416
# Epoch: 5 | Train Loss: 79.1680
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[254765 135731  34542  13167   5771   2858   1421    794    836     57]
#  [ 77260 100772  42900  21136   9961   4953   2766   1485   1859    150]
#  [ 25301  54399  33910  20978  11538   6312   3565   2143   2953    293]
#  [ 10076  27966  23172  16766  10929   6784   4082   2634   3986    392]
#  [  4190  14775  14766  13267   9368   6738   4515   2705   4669    549]
#  [  2025   8573  10032   9712   8096   5731   4256   2785   5237    701]
#  [  1081   4591   6550   7466   6128   4907   3736   2584   5549    868]
#  [   699   2849   4339   5250   5042   4006   3290   2441   5827    882]
#  [  1090   5210   9260  12670  13823  13813  12651  10875  27179   4625]
#  [   367   2150   3478   5760   6730   7217   8007   7923  24896   5160]]
# Mean absolute deviation (MAD) = 2.346189413260104
# Mean squared error (MSE) = 50.902477515526364
# Mean absolute percentage error (MAPE) = 112.71754344165257
# Mean squared logarithmic error (MSLE) = 1.1225426756104837
# R^2 Score = 0.17470937800919406
# Cohen kappa score = 0.5015893804469129
# Epoch: 5 | Validation Loss: 70.0635
# Train Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[1216786  656186  139230   48392   20274    9630    5012    2712    4230
#       551]
#  [ 426016  490353  172343   74640   34303   17351    9342    5150    7946
#      1007]
#  [ 161218  282832  145828   76147   39753   21696   12223    7110   11517
#      1669]
#  [  67691  160342  111167   67443   38600   22320   13511    8181   14474
#      2301]
#  [  31797   93209   80586   55565   34970   21841   13478    8754   16176
#      2900]
#  [  16068   56414   57796   45083   30694   20122   13100    8645   16749
#      3384]
#  [   8744   34543   41897   36468   26284   18078   12294    8373   16949
#      3810]
#  [   5103   21291   30177   28673   22461   16094   11139    7847   16808
#      4148]
#  [   9295   44259   74074   83760   73185   57801   43739   32076   78824
#     24813]
#  [   3026   16124   31571   41879   43103   38110   31517   25256   73298
#     32944]]
# Mean absolute deviation (MAD) = 2.4396167586428765
# Mean squared error (MSE) = 28.91781346019984
# Mean absolute percentage error (MAPE) = 109.92482755514
# Mean squared logarithmic error (MSLE) = 1.2347673383058222
# R^2 Score = 0.21125365420207587
# Cohen kappa score = 0.43459043086023363
# Epoch: 6 | Train Loss: 77.6864
# Validation Metrics:
# ==> Length of Stay:
# Custom bins confusion matrix:
# [[257841 134248  33886  12515   5518   2947   1441    736    782     28]
#  [ 77330 101004  43063  20642   9980   4934   2732   1475   1953    129]
#  [ 24920  54340  34066  21130  11200   6418   3824   2243   2970    281]
#  [  9736  27553  23492  16802  10780   7076   4124   2587   4181    456]
#  [  4034  14449  14778  13030   9562   6775   4503   2899   4866    646]
#  [  1912   8289   9894   9703   7963   5837   4269   2888   5504    889]
#  [  1022   4306   6432   7379   6223   4788   3618   2720   5886   1086]
#  [   646   2705   4168   5216   4856   3955   3324   2531   6102   1122]
#  [  1032   4811   8798  12104  13415  13159  12328  10712  28879   5958]
#  [   342   2029   3064   5242   6282   7109   7642   7292  26071   6615]]
# Mean absolute deviation (MAD) = 2.32381480179545
# Mean squared error (MSE) = 50.534920047521375
# Mean absolute percentage error (MAPE) = 110.96236533222184
# Mean squared logarithmic error (MSLE) = 1.0989230846270703
# R^2 Score = 0.18066865044921776
# Cohen kappa score = 0.5131279241328806
# Epoch: 6 | Validation Loss: 68.5899

# %% [markdown]
# # New Section
